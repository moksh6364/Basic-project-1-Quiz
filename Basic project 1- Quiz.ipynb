# %%
print("Welcome to the quiz game!")
score = 0
correct = 0
incorrect = 0
playing= " "

rule = "Will be asking 5 questions and for each correct answer you get +1 and for wrong answer -0.33"

while playing not in ("yes","no"):
    playing = input("Do you wanna play? yes or no? ").lower()
    
    if playing not in ("yes","no"):
        print("Provide valid input")

    if playing == "no":
        print("As you wish.")
        break

    if playing == "yes":
        print(rule)
        print("Let's play!\n")


print("1st question")
answer1 = input("What is full form of USA? ").lower()
if answer1 == "united states of america":
    print("Correct!")
    score += 1
    correct += 1
else: 
    print("Incorrect!")
    score -= 0.33
    incorrect += 1
    pass
    
print("2nd question")
answer2 = input("Who is prime minister of India? ").lower()
if answer2 == "narender modi":
    print("Correct!")
    score += 1
    correct += 1
else: 
    print("Incorrect!")
    score -= 0.33
    incorrect += 1
    pass
    
print("3rd question")
answer3 = input("Longest river in India? ").lower()
if answer3 == "indus":
    print("Correct!")
    score += 1
    correct += 1
else: 
    print("Incorrect!")
    score -= 0.33
    incorrect += 1
    pass
    
print("4th question")
answer4 = input("Largest planet in solar system? ").lower()
if answer4 == "jupiter":
    print("Correct!")
    score += 1
    correct += 1
else: 
    print("Incorrect!")
    score -= 0.33
    incorrect += 1
    pass
    
print("5th question")
answer5 = input("What is full form of DBMS? ").lower()
if answer5 == "database management system":
    print("Correct!")
    score += 1
    correct += 1
else: 
    print("Incorrect!")
    score -= 0.33
    incorrect += 1
    pass

print ("\nCongratulations game over! you're score is ",score)
print ("Correct answers: " + str(correct))
print ("Wrong answers: " + str(incorrect))
print ("You scored " + str((correct/5)*100) +"%")
